# %%
from section_identification.section_detector import section_detector
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.eye(10)
plt.imshow(image)

# %%
segmentation = section_detector(image)
plt.imshow(segmentation)
